# %% [markdown]
# ## **Data Insight Generator** ##

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading dataset
df = pd.read_csv("sales_data.csv")

# %%
# Step 2: Show first few rows
print("📊 Preview of Data:")
df.head()
# Out:
# 📊 Preview of Data:
#          Date Product  Sales  Quantity
# 0  2024-01-01   Phone  50000         5
# 1  2024-01-02  Laptop  90000         3
# 2  2024-01-03  Tablet  30000         4
# 3  2024-01-04   Phone  40000         4
# 4  2024-01-05  Laptop  95000         5

# %%
df.describe()
# Out:
#                Sales   Quantity
# count      31.000000  31.000000
# mean    53129.032258   6.193548
# std     32934.016797   1.796652
# min     15000.000000   3.000000
# 25%     24000.000000   5.000000
# 50%     42000.000000   6.000000
# 75%     77500.000000   7.000000
# max    120000.000000  10.000000

# %%
# step 3 data cleaning
df.dropna(inplace=True)
df['Sales'] = df['Sales'].astype(float)

# %%
# step 4 calculations
total_sales = df['Sales'].sum()
average_order_value = df['Sales'].mean()
best_selling_product = df.groupby('Product')['Sales'].sum().idxmax()

# %%
print("\n📈 Key Insights:")
print(f"Total Sales: {total_sales}")
print(f"Average Order Value: {average_order_value:.2f}")
print(f"Best-Selling Product: {best_selling_product}")
# Out:
# 📈 Key Insights:
# Total Sales: 1647000.0
# Average Order Value: 53129.03
# Best-Selling Product: Laptop

# %%
# Insight generate with visualization
plt.figure(figsize=(8, 5))
sns.barplot(
    x='Product',
    y='Sales',
    data=df,
    estimator=sum,
    errorbar=None,       # replaces ci=None
    hue='Product',       # adds color variety for each product
    palette='Set2',
    legend=False         # hides extra legend
)
plt.title("Total Sales by Product", fontsize=14, fontweight='bold')
plt.xlabel("Product", fontsize=12)
plt.ylabel("Sales (in PKR)", fontsize=12)
plt.show()
